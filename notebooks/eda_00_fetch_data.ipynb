# %%
# %pip install -r ../requirements.txt
# Out:
# Requirement already satisfied: absl-py==2.3.1 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 1)) (2.3.1)
# Requirement already satisfied: asttokens==3.0.0 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 2)) (3.0.0)
# Requirement already satisfied: astunparse==1.6.3 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 3)) (1.6.3)
# Requirement already satisfied: beautifulsoup4==4.14.2 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 4)) (4.14.2)
# Requirement already satisfied: certifi==2025.8.3 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 5)) (2025.8.3)
# Requirement already satisfied: charset-normalizer==3.4.3 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 6)) (3.4.3)
# Requirement already satisfied: colorama==0.4.6 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 7)) (0.4.6)
# Requirement already satisfied: comm==0.2.3 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 8)) (0.2.3)
# Requirement already satisfied: contourpy==1.3.3 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 9)) (1.3.3)
# Requirement already satisfied: cycler==0.12.1 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 10)) (0.12.1)
# Requirement already satisfied: debugpy==1.8.17 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 11)) (1.8.17)
# Requirement already satisfied: decorator==5.2.1 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 12)) (5.2.1)
# Requirement already satisfied: executing==2.2.1 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 13)) (2.2.1)
# Requirement already satisfied: filelock==3.19.1 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 14)) (3.19.1)
# Requirement already satisfied: flatbuffers==25.9.23 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 15)) (25.9.23)
# Requirement already satisfied: fonttools==4.60.1 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 16)) (4.60.1)
# Requirement already satisfied: gast==0.6.0 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 17)) (0.6.0)
# Requirement already satisfied: gdown==5.2.0 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 18)) (5.2.0)
# Requirement already satisfied: google-pasta==0.2.0 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 19)) (0.2.0)
# Requirement already satisfied: grpcio==1.76.0 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 20)) (1.76.0)
# Requirement already satisfied: h5py==3.15.1 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 21)) (3.15.1)
# Requirement already satisfied: idna==3.10 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 22)) (3.10)
# Requirement already satisfied: ipykernel==6.30.1 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 23)) (6.30.1)
# Requirement already satisfied: ipython==9.6.0 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 24)) (9.6.0)
# Requirement already satisfied: ipython_pygments_lexers==1.1.1 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 25)) (1.1.1)
# Requirement already satisfied: jedi==0.19.2 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 26)) (0.19.2)
# Requirement already satisfied: joblib==1.5.2 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 27)) (1.5.2)
# Requirement already satisfied: jupyter_client==8.6.3 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 28)) (8.6.3)
# Requirement already satisfied: jupyter_core==5.8.1 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 29)) (5.8.1)
# Requirement already satisfied: keras==3.11.3 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 30)) (3.11.3)
# Requirement already satisfied: kiwisolver==1.4.9 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 31)) (1.4.9)
# Requirement already satisfied: libclang==18.1.1 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 32)) (18.1.1)
# Requirement already satisfied: Markdown==3.9 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 33)) (3.9)
# Requirement already satisfied: markdown-it-py==4.0.0 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 34)) (4.0.0)
# Requirement already satisfied: MarkupSafe==3.0.3 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 35)) (3.0.3)
# Requirement already satisfied: matplotlib==3.10.6 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 36)) (3.10.6)
# Requirement already satisfied: matplotlib-inline==0.1.7 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 37)) (0.1.7)
# Requirement already satisfied: mdurl==0.1.2 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 38)) (0.1.2)
# Requirement already satisfied: ml_dtypes==0.5.3 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 39)) (0.5.3)
# Requirement already satisfied: namex==0.1.0 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 40)) (0.1.0)
# Requirement already satisfied: nest-asyncio==1.6.0 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 41)) (1.6.0)
# Requirement already satisfied: numpy==2.3.3 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 42)) (2.3.3)
# Requirement already satisfied: opt_einsum==3.4.0 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 43)) (3.4.0)
# Requirement already satisfied: optree==0.17.0 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 44)) (0.17.0)
# Requirement already satisfied: packaging==25.0 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 45)) (25.0)
# Requirement already satisfied: pandas==2.3.3 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 46)) (2.3.3)
# Requirement already satisfied: parso==0.8.5 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 47)) (0.8.5)
# Requirement already satisfied: pillow==11.3.0 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 48)) (11.3.0)
# Requirement already satisfied: platformdirs==4.4.0 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 49)) (4.4.0)
# Requirement already satisfied: prompt_toolkit==3.0.52 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 50)) (3.0.52)
# Requirement already satisfied: protobuf==6.33.0 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 51)) (6.33.0)
# Requirement already satisfied: psutil==7.1.0 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 52)) (7.1.0)
# Requirement already satisfied: pure_eval==0.2.3 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 53)) (0.2.3)
# Requirement already satisfied: pyarrow==21.0.0 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 54)) (21.0.0)
# Requirement already satisfied: Pygments==2.19.2 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 55)) (2.19.2)
# Requirement already satisfied: pyparsing==3.2.5 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 56)) (3.2.5)
# Requirement already satisfied: PySocks==1.7.1 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 57)) (1.7.1)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 58)) (2.9.0.post0)
# Requirement already satisfied: pytz==2025.2 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 59)) (2025.2)
# Requirement already satisfied: pywin32==311 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 60)) (311)
# Requirement already satisfied: pyzmq==27.1.0 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 61)) (27.1.0)
# Requirement already satisfied: requests==2.32.5 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 62)) (2.32.5)
# Requirement already satisfied: rich==14.2.0 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 63)) (14.2.0)
# Requirement already satisfied: scikit-learn==1.7.2 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 64)) (1.7.2)
# Requirement already satisfied: scipy==1.16.2 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 65)) (1.16.2)
# Requirement already satisfied: seaborn==0.13.2 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 66)) (0.13.2)
# Requirement already satisfied: setuptools==80.9.0 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 67)) (80.9.0)
# Requirement already satisfied: six==1.17.0 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 68)) (1.17.0)
# Requirement already satisfied: soupsieve==2.8 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 69)) (2.8)
# Requirement already satisfied: stack-data==0.6.3 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 70)) (0.6.3)
# Requirement already satisfied: tensorboard==2.20.0 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 71)) (2.20.0)
# Requirement already satisfied: tensorboard-data-server==0.7.2 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 72)) (0.7.2)
# Collecting tensorflow==2.20.0 (from -r ../requirements.txt (line 73))
#   Using cached tensorflow-2.20.0-cp311-cp311-win_amd64.whl.metadata (4.6 kB)
# Requirement already satisfied: termcolor==3.1.0 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 74)) (3.1.0)
# Requirement already satisfied: threadpoolctl==3.6.0 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 75)) (3.6.0)
# Requirement already satisfied: tornado==6.5.2 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 76)) (6.5.2)
# Requirement already satisfied: tqdm==4.67.1 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 77)) (4.67.1)
# Requirement already satisfied: traitlets==5.14.3 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 78)) (5.14.3)
# Requirement already satisfied: typing_extensions==4.15.0 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 79)) (4.15.0)
# Requirement already satisfied: tzdata==2025.2 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 80)) (2025.2)
# Requirement already satisfied: urllib3==2.5.0 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 81)) (2.5.0)
# Requirement already satisfied: wcwidth==0.2.14 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 82)) (0.2.14)
# Requirement already satisfied: Werkzeug==3.1.3 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 83)) (3.1.3)
# Requirement already satisfied: wheel==0.45.1 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 84)) (0.45.1)
# Requirement already satisfied: wrapt==2.0.0 in c:\users\samuel\documents\noveno semestre\aprendizaje maquina\stocksalmon\.venv\lib\site-packages (from -r ../requirements.txt (line 85)) (2.0.0)
# Using cached tensorflow-2.20.0-cp311-cp311-win_amd64.whl (331.8 MB)
# Installing collected packages: tensorflow
# Successfully installed tensorflow-2.20.0
# Note: you may need to restart the kernel to use updated packages.

# %%
RAW_DIR = "../data/raw"
DRIVE_FILE_ID = "1ApZqHWxtuhxrNqdL-odfDxxIceoCiA2z"  # Drive público con Datasets
ZIP_NAME = "archive.zip"

REQUIRED_FILES = [
    "chessData.csv",
    "random_evals.csv",
    "tactic_evals.csv",
]

# %%
from pathlib import Path
import zipfile
import sys
import gdown

raw_dir = Path(RAW_DIR)
raw_dir.mkdir(parents=True, exist_ok=True)

required_paths = [raw_dir / f for f in REQUIRED_FILES]
zip_path = raw_dir / ZIP_NAME

def all_exist(paths):
    return all(p.is_file() for p in paths)

if all_exist(required_paths):
    print("✅ Archivos ya presentes en data/raw. Nada que hacer.")
else:
    # Descarga el ZIP si no está
    if not zip_path.exists():
        url = f"https://drive.google.com/uc?id={DRIVE_FILE_ID}"
        print(f"⬇️ Descargando {ZIP_NAME} desde Drive a {zip_path} ...")
        gdown.download(url, str(zip_path), quiet=False)

    if not zip_path.exists():
        raise RuntimeError("No se pudo descargar el ZIP desde Drive.")

    # Descomprimir
    print(f"📦 Descomprimiendo {zip_path} en {raw_dir} ...")
    with zipfile.ZipFile(zip_path, "r") as zf:
        zf.extractall(raw_dir)

    # Verificación final
    missing = [p.name for p in required_paths if not p.exists()]
    if missing:
        print("⚠️ Faltan archivos tras descomprimir:", missing, file=sys.stderr)
        raise FileNotFoundError(f"Faltan: {missing}")
    else:
        print("✅ Archivos listos en data/raw.")
# Out:
# ⬇️ Descargando archive.zip desde Drive a ..\data\raw\archive.zip ...
# Downloading...
# From (original): https://drive.google.com/uc?id=1ApZqHWxtuhxrNqdL-odfDxxIceoCiA2z
# From (redirected): https://drive.google.com/uc?id=1ApZqHWxtuhxrNqdL-odfDxxIceoCiA2z&confirm=t&uuid=2bea5306-0c35-4475-9db7-54387108b10b
# To: c:\Users\Samuel\Documents\noveno semestre\aprendizaje maquina\stocksalmon\data\raw\archive.zip
# 100%|██████████| 209M/209M [01:07<00:00, 3.08MB/s]
# 📦 Descomprimiendo ..\data\raw\archive.zip en ..\data\raw ...
# ✅ Archivos listos en data/raw.
